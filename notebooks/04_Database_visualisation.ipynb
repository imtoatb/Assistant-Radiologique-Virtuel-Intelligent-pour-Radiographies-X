# %% [markdown]
# # 04 — Visualisations des tables de la database and logs

# %%
import sys
from pathlib import Path
sys.path.append(str(Path('..').resolve()))
from src.database import get_runs, get_evaluations, get_cases, get_prompts
import pandas as pd

DB_PATH = Path('..') / 'data' / 'database.sqlite'

# %% [markdown]
# ### `Cases` table

# %%
display(pd.DataFrame(get_cases(DB_PATH)))
# Out:
#       id                                         image_path  \
# 0      1  data/brutes/ABNORMAL-LUNG_00001_suspected_opac...
# 1      2  data/brutes/ABNORMAL-LUNG_00002_suspected_opac...
# 2      3  data/brutes/ABNORMAL-LUNG_00003_suspected_opac...
# 3      4  data/brutes/ABNORMAL-LUNG_00004_suspected_opac...
# 4      5  data/brutes/ABNORMAL-LUNG_00005_suspected_opac...
# ..   ...                                                ...
# 927  928       data/brutes/NORMAL-LUNG_00928_normal_567.jpg
# 928  929       data/brutes/NORMAL-LUNG_00929_normal_568.jpg
# 929  930       data/brutes/NORMAL-LUNG_00930_normal_569.jpg
# 930  931       data/brutes/NORMAL-LUNG_00931_normal_570.jpg
# 931  932       data/brutes/NORMAL-LUNG_00932_normal_571.jpg
#
#                       source ground_truth_label     split  \
# 0    fkarimovv/abnormal-lung  suspected_opacity  external
# 1    fkarimovv/abnormal-lung  suspected_opacity  external
# 2    fkarimovv/abnormal-lung  suspected_opacity  external
# 3    fkarimovv/abnormal-lung  suspected_opacity  external
# 4    fkarimovv/abnormal-lung  suspected_opacity  external
# ..                       ...                ...       ...
# 927  fkarimovv/abnormal-lung             normal  external
# 928  fkarimovv/abnormal-lung             normal  external
# 929  fkarimovv/abnormal-lung             normal  external
# 930  fkarimovv/abnormal-lung             normal  external
# 931  fkarimovv/abnormal-lung             normal  external
#
#                                                  notes
# 0    Importé depuis ABNORMAL-LUNG_00001_suspected_o...
# 1    Importé depuis ABNORMAL-LUNG_00002_suspected_o...
# 2    Importé depuis ABNORMAL-LUNG_00003_suspected_o...
# 3    Importé depuis ABNORMAL-LUNG_00004_suspected_o...
# 4    Importé depuis ABNORMAL-LUNG_00005_suspected_o...
# ..                                                 ...
# 927    Importé depuis NORMAL-LUNG_00928_normal_567.jpg
# 928    Importé depuis NORMAL-LUNG_00929_normal_568.jpg
# 929    Importé depuis NORMAL-LUNG_00930_normal_569.jpg
# 930    Importé depuis NORMAL-LUNG_00931_normal_570.jpg
# 931    Importé depuis NORMAL-LUNG_00932_normal_571.jpg
#
# [932 rows x 6 columns]

# %% [markdown]
# ### `Runs` table

# %%
display(pd.DataFrame(get_runs(DB_PATH)))
# Out:
#       id  case_id  prompt_id  \
# 0    224      622          3
# 1    223      620          3
# 2    222       19          3
# 3    221       18          3
# 4    220      604          3
# ..   ...      ...        ...
# 219    5      616          1
# 220    4      466          1
# 221    3      500          1
# 222    2      640          1
# 223    1       17          1
#
#                                             image_path      model_name  \
# 0    C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 1    C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 2    C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 3    C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 4    C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# ..                                                 ...             ...
# 219  C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 220  C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 221  C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 222  C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
# 223  C:\Users\auber.MSI\Projets\TD-Mastercamp\Solut...  medgemma-4b-it
#
#                                        prediction_json predicted_class  \
# 0    {"image_quality": "good", "predicted_class": "...          normal
# 1    {"image_quality": "good", "predicted_class": "...          normal
# 2    {"image_quality": "good", "predicted_class": "...          normal
# 3    {"image_quality": "good", "predicted_class": "...          normal
# 4    {"image_quality": "good", "predicted_class": "...          normal
# ..                                                 ...             ...
# 219  {"image_quality": "good", "predicted_class": "...          normal
# 220  {"image_quality": "good", "predicted_class": "...          normal
# 221  {"image_quality": "good", "predicted_class": "...          normal
# 222  {"image_quality": "good", "predicted_class": "...          normal
# 223  {"image_quality": "good", "predicted_class": "...          normal
#
#      confidence  latency_ms           created_at
# 0          0.80       34896  2026-06-29 06:55:44
# 1          0.80       43880  2026-06-29 06:55:09
# 2          0.80       40502  2026-06-29 06:54:25
# 3          0.80       42063  2026-06-29 06:53:45
# 4          0.80       37090  2026-06-29 06:40:34
# ..          ...         ...                  ...
# 219        0.95       53350  2026-06-29 00:25:12
# 220        0.95       38726  2026-06-29 00:24:19
# 221        0.95       38410  2026-06-29 00:23:40
# 222        0.95       47196  2026-06-29 00:23:01
# 223        0.95       52971  2026-06-29 00:22:14
#
# [224 rows x 10 columns]

# %% [markdown]
# ### `Evaluations` Table

# %%
display(pd.DataFrame(get_evaluations(DB_PATH)))
# Out:
#      case_id  run_id  evaluation_id  prompt_id prompt_name prompt_version  \
# 0         17       1              1          1    baseline             v0
# 1         29      83             83          1    baseline             v0
# 2         34      50             50          1    baseline             v0
# 3         37      55             55          1    baseline             v0
# 4         72      62             62          1    baseline             v0
# ..       ...     ...            ...        ...         ...            ...
# 219      620     223            223          3    improved             v2
# 220      622     224            224          3    improved             v2
# 221      648     204            204          3    improved             v2
# 222      670     202            202          3    improved             v2
# 223      701     203            203          3    improved             v2
#
#     ground_truth_label predicted_class  confidence  latency
# 0    suspected_opacity          normal        0.95    52971
# 1    suspected_opacity          normal        0.95    35864
# 2    suspected_opacity          normal        0.95    39044
# 3    suspected_opacity          normal        0.80    44824
# 4    suspected_opacity          normal        0.95    35904
# ..                 ...             ...         ...      ...
# 219             normal          normal        0.80    43880
# 220             normal          normal        0.80    34896
# 221             normal          normal        0.80    42864
# 222             normal          normal        0.80    47972
# 223             normal          normal        0.80    34332
#
# [224 rows x 10 columns]

# %% [markdown]
# ### `Prompts` table

# %%
display(pd.DataFrame(get_prompts(DB_PATH)))
# Out:
#    id prompt_name prompt_version  \
# 0   3    improved             v2
# 1   1    baseline             v0
# 2   2    improved             v1
#
#                                          prompt_text           created_at
# 0  You are an educational radiology assistant for...  2026-06-29 06:03:52
# 1  You are an educational radiology assistant for...  2026-06-28 23:42:14
# 2  You are an educational radiology assistant for...  2026-06-28 23:42:14
